# %%
# %load_ext autoreload
# %autoreload 2

# %load_ext watermark
# %watermark -a "Johann" -v -n -p numpy,scipy,sklearn,pandas
# Out:
# Johann Thu Oct 08 2020
#
# CPython 3.8.5
# IPython 7.18.1
#
# numpy 1.19.2
# scipy 1.5.2
# sklearn 0.23.2
# pandas 1.1.0

# %%
import os
import time
import pandas as pd
from pathlib import Path
from pyprojroot import here

data_path = Path(here('./data/raw'))

# %% [markdown]
# Statistical data: { "data": [ "date" :
#                               "Incidents_number":
#                               "lat":
#                               "lon":
#                               "lethal":
#                               "Projectile":
#                               "Race_victim":
#                               "Race_police_officer":
#                               "Victim_gender":
#                               "police_officer_Gender":
#                              ]
#                   }

# %%
def convert_dtype(x):
    if not x:
        return ''
    try:
        return str(x)   
    except:        
        return ''

pd.read_csv('file.csv',converters={'first_column': convert_dtype,'second_column': convert_dtype})

# %%
police_initiative = pd.read_csv(data_path / 'police_initiative.csv', low_memory=False)

# %%
police_initiative.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Incident Number      Incident Date Time  \
# 0           0             0   2018-00079161  02/25/2018 10:23:00 PM
# 1           1             1   2013-00544482  12/29/2013 11:02:00 PM
# 2           2             2   2018-00478744  12/14/2018 08:17:00 AM
# 3           3             3   2017-00316840  08/14/2017 01:50:00 AM
# 4           4             4  IncidentNumber                     NaN
#
#           Incident Location  Officers Involved Officers Race  \
# 0     26TH / 15 LAWSONA BLV                1.0             W
# 1                       NaN                1.0             B
# 2  9200 Block of AIRPORT BV                1.0             W
# 3          EW WBO / LONG ST                3.0         W;W;W
# 4          IncidentLocation                NaN  OfficersRace
#
#   Officers Ethnicity Officers Sex Officer Battered  ... Unnamed: 21  \
# 0                 NH            M              Yes  ...         NaN
# ...

# %%
police_initiative.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94464 entries, 0 to 94463
# Data columns (total 457 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   Unnamed: 0                                                            int64
#  1   Unnamed: 0.1                                                          int64
#  2   Incident Number                                                       object
#  3   Incident Date Time                                                    object
#  4   Incident Location                                                     object
#  5   Officers Involved                                                     float64
#  6   Officers Race                                                         object
#  7   Officers Ethnicity                                                    object
# ...

# %%
col = police_initiative.columns.tolist()
col
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'Incident Number',
#  'Incident Date Time',
#  'Incident Location',
#  'Officers Involved',
#  'Officers Race',
#  'Officers Ethnicity',
#  'Officers Sex',
#  'Officer Battered',
#  'Officer Injured',
#  'Officer Medical Treatment',
#  'Electronic Device Used',
#  'Chemical Agent Used',
#  'Tackle Take Down',
#  'Impact Weapons Used',
#  'Physical Strikes Made',
#  'Deflation Device Used',
#  'K9 Unit Involved',
#  'Offenders Involved',
#  'Offenders Race',
#  'Offenders Ethnicity',
#  'Offenders Sex',
#  'Offender Arrested',
#  'Offender Injured',
#  'Offender Medical Treatment',
#  'Witnesses Involved',
#  'Status',
#  'Location',
#  'State',
#  'City',
#  'Blunt Object',
#  'Category of Force Event - Measured at Event Level',
#  'Disposition/Custody',
#  'DOW',
#  'Firearm',
#  'Firearm - Implied',
#  'Firearm - Replica',
#  'Force Applied - 1',
#  'Force Applied - 2',
#  'Force Applied - 3',
#  'Force Applied - 4',
#  'Force Applied - 5',
# ...

# %%
cols = ['Incident Number', 'Incident Date Time', 'State', 'City', 'LATITUDE_X', 'LONGITUDE_X', 
 'Officers Involved', 'Officers Race', 'Officers Ethnicity', 'Officers Sex', 'OffSex', 'OffSex', 'GeoLocation',  'Subject - Race',
 'Subject - Sex']

# %%
pi = pd.read_csv(data_path / 'police_initiative.csv', low_memory=False, usecols=cols)

# %%
pi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94464 entries, 0 to 94463
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Incident Number     5658 non-null   object
#  1   Incident Date Time  5656 non-null   object
#  2   Officers Involved   5656 non-null   float64
#  3   Officers Race       5658 non-null   object
#  4   Officers Ethnicity  5658 non-null   object
#  5   Officers Sex        5658 non-null   object
#  6   State               94464 non-null  object
#  7   City                94464 non-null  object
#  8   Subject - Race      5238 non-null   object
#  9   Subject - Sex       5240 non-null   object
#  10  LATITUDE_X          11859 non-null  float64
#  11  LONGITUDE_X         11859 non-null  float64
#  12  OffSex              20609 non-null  object
#  13  GeoLocation         16640 non-null  object
# dtypes: float64(3), object(11)
# memory usage: 10.1+ MB
